# %% [markdown]
# ## Athul Krishna
#
# ## Final project, regression problem

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv")

# %%
df.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# 2                                   1-02138-0030
# 3                                   1-02139-0001
# 4                                   1-02139-0085
#
#             NYC Building Identification Number (BIN)  \
# 0                                            1037549
# 1  1084198; 1084387;1084385; 1084386; 1084388; 10...
# 2                                            1063380
# 3                                   1087281; 1076746
# 4                                            1063403
#
#   Address 1 (self-reported)                Address 2  ...  \
# 0  201/205  East  42nd  st.            Not Available  ...
# 1          622 168th Street            Not Available  ...
# 2             3975 Broadway            Not Available  ...
# 3   161 Fort Washington Ave  177 Fort Washington Ave  ...
# 4     710 West 168th Street            Not Available  ...
#
#   Source EUI (kBtu/ft²)            Release Date Water Required?  \
# 0                 619.4  05/01/2017 05:32:03 PM              No
# 1                 404.3  04/27/2017 11:23:27 AM              No
# 2         Not Available  04/27/2017 11:23:27 AM              No
# 3         Not Available  04/27/2017 11:23:27 AM              No
# 4         Not Available  04/27/2017 11:23:27 AM              No
#
#   DOF Benchmarking Submission Status   Latitude  Longitude Community Board  \
# 0                      In Compliance  40.750791 -73.973963             6.0
# 1                      In Compliance  40.841402 -73.942568            12.0
# 2                      In Compliance  40.840427 -73.940249            12.0
# 3                      In Compliance  40.840746 -73.942854            12.0
# 4                      In Compliance  40.841559 -73.942528            12.0
#
#   Council District Census Tract  \
# 0              4.0         88.0
# 1             10.0        251.0
# 2             10.0        251.0
# 3             10.0        255.0
# 4             10.0        255.0
#
#                                                  NTA
# 0  Turtle Bay-East Midtown                       ...
# 1  Washington Heights South                      ...
# 2  Washington Heights South                      ...
# 3  Washington Heights South                      ...
# 4  Washington Heights South                      ...
#
# [5 rows x 60 columns]

# %%
df.describe()
# Out:
#               Order   Property Id  DOF Gross Floor Area    Year Built  \
# count  11746.000000  1.174600e+04          1.162800e+04  11746.000000
# mean    7185.759578  3.642958e+06          1.732695e+05   1948.738379
# std     4323.859984  1.049070e+06          3.367055e+05     30.576386
# min        1.000000  7.365000e+03          5.002800e+04   1600.000000
# 25%     3428.250000  2.747222e+06          6.524000e+04   1927.000000
# 50%     6986.500000  3.236404e+06          9.313850e+04   1941.000000
# 75%    11054.500000  4.409092e+06          1.596140e+05   1966.000000
# max    14993.000000  5.991312e+06          1.354011e+07   2019.000000
#
#        Number of Buildings - Self-reported     Occupancy  \
# count                         11746.000000  11746.000000
# mean                              1.289971     98.762557
# std                               4.017484      7.501603
# min                               0.000000      0.000000
# 25%                               1.000000    100.000000
# 50%                               1.000000    100.000000
# 75%                               1.000000    100.000000
# max                             161.000000    100.000000
#
#        Property GFA - Self-Reported (ft²)     Latitude    Longitude  \
# count                        1.174600e+04  9483.000000  9483.000000
# mean                         1.673739e+05    40.754379   -73.957057
# std                          3.189238e+05     0.080120     0.046337
# min                          0.000000e+00    40.516065   -74.243582
# 25%                          6.699400e+04    40.707226   -73.984662
# 50%                          9.408000e+04    40.759130   -73.962810
# 75%                          1.584140e+05    40.817623   -73.932443
# max                          1.421712e+07    40.912869   -73.715543
#
#        Community Board  Council District   Census Tract
# count      9483.000000       9483.000000    9483.000000
# mean          7.140673         15.771275    4977.596647
# std           3.954129         15.674375   13520.422990
# min           1.000000          1.000000       1.000000
# 25%           4.000000          4.000000     100.000000
# 50%           7.000000          9.000000     201.000000
# 75%           9.000000         33.000000     531.500000
# max          56.000000         51.000000  155101.000000

# %%
df.iloc[0:16,28:41]
# Out:
#    ENERGY STAR Score Site EUI (kBtu/ft²)  \
# 0      Not Available               305.6
# 1                 55               229.8
# 2      Not Available       Not Available
# 3      Not Available       Not Available
# 4      Not Available       Not Available
# 5                 55               359.9
# 6      Not Available       Not Available
# 7      Not Available            143974.4
# 8      Not Available              1138.3
# 9      Not Available       Not Available
# 10     Not Available       Not Available
# 11     Not Available       Not Available
# 12                93                  32
# 13                 1               295.4
# 14                80               352.7
# 15     Not Available       Not Available
#
#    Weather Normalized Site EUI (kBtu/ft²)  \
# 0                                   303.1
# 1                                   228.8
# 2                           Not Available
# 3                           Not Available
# 4                           Not Available
# 5                                     359
# 6                           Not Available
# 7                                  143976
# 8                                  1091.5
# 9                           Not Available
# 10                          Not Available
# 11                          Not Available
# 12                          Not Available
# 13                                  316.8
# 14                          Not Available
# 15                          Not Available
#
#    Weather Normalized Site Electricity Intensity (kWh/ft²)  \
# 0                                                37.8
# 1                                                24.8
# 2                                       Not Available
# 3                                       Not Available
# 4                                       Not Available
# 5                                                 8.3
# 6                                       Not Available
# 7                                       Not Available
# 8                                               319.9
# 9                                       Not Available
# 10                                      Not Available
# 11                                      Not Available
# 12                                                7.5
# 13                                                5.8
# 14                                               32.2
# 15                                      Not Available
#
#    Weather Normalized Site Natural Gas Intensity (therms/ft²)  \
# 0                                       Not Available
# 1                                                 2.4
# 2                                       Not Available
# 3                                       Not Available
# 4                                       Not Available
# 5                                                 4.8
# 6                                       Not Available
# 7                                              1439.7
# 8                                       Not Available
# 9                                       Not Available
# 10                                      Not Available
# 11                                      Not Available
# 12                                                  0
# 13                                                  3
# 14                                                2.2
# 15                                      Not Available
#
#    Weather Normalized Source EUI (kBtu/ft²) Fuel Oil #1 Use (kBtu)  \
# 0                                     614.2          Not Available
# 1                                     401.1          Not Available
# 2                             Not Available          Not Available
# 3                             Not Available          Not Available
# 4                             Not Available          Not Available
# 5                                     411.5          Not Available
# 6                             Not Available          Not Available
# 7                                  151174.5          Not Available
# 8                                    3427.3          Not Available
# 9                             Not Available          Not Available
# 10                            Not Available          Not Available
# 11                            Not Available          Not Available
# 12                            Not Available          Not Available
# 13                                    374.2          Not Available
# 14                            Not Available          Not Available
# 15                            Not Available          Not Available
#
#    Fuel Oil #2 Use (kBtu) Fuel Oil #4 Use (kBtu) Fuel Oil #5 & 6 Use (kBtu)  \
# 0           Not Available          Not Available              Not Available
# 1            1.96248472E7          Not Available              Not Available
# 2           Not Available          Not Available              Not Available
# 3           Not Available          Not Available              Not Available
# 4           Not Available          Not Available              Not Available
# 5            2.00832154E7          Not Available              Not Available
# 6           Not Available          Not Available              Not Available
# 7            1.37367028E7          Not Available              Not Available
# 8           Not Available          Not Available              Not Available
# 9           Not Available          Not Available              Not Available
# 10          Not Available          Not Available              Not Available
# 11          Not Available          Not Available              Not Available
# 12          Not Available          Not Available              Not Available
# 13          Not Available          Not Available              Not Available
# 14              9230304.1          Not Available              Not Available
# 15          Not Available          Not Available              Not Available
#
#    Diesel #2 Use (kBtu) District Steam Use (kBtu) Natural Gas Use (kBtu)
# 0         Not Available              5.15506751E7          Not Available
# 1         Not Available            -3.914148026E8              933073441
# 2         Not Available             Not Available          Not Available
# 3         Not Available             Not Available          Not Available
# 4         Not Available             Not Available          Not Available
# 5         Not Available            -4.690796909E8         1.4322508769E9
# 6         Not Available             Not Available          Not Available
# 7         Not Available             Not Available           394285242148
# 8         Not Available             Not Available          Not Available
# 9         Not Available             Not Available          Not Available
# 10        Not Available             Not Available          Not Available
# 11        Not Available             Not Available          Not Available
# 12        Not Available             Not Available                2047200
# 13        Not Available             Not Available           4.75229012E7
# 14        Not Available             Not Available          1.284867131E8
# 15        Not Available             Not Available          Not Available

# %%
df[["ENERGY STAR Score"]].value_counts()
# Out:
# ENERGY STAR Score
# Not Available        2104
# 100                   649
# 1                     299
# 99                    162
# 80                    144
#                      ...
# 17                     48
# 12                     47
# 42                     47
# 21                     46
# 11                     44
# Name: count, Length: 101, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11746 non-null  int64
#  1   Property Id                                                 11746 non-null  int64
#  2   Property Name                                               11746 non-null  object
#  3   Parent Property Id                                          11746 non-null  object
#  4   Parent Property Name                                        11746 non-null  object
#  5   BBL - 10 digits                                             11735 non-null  object
#  6   NYC Borough, Block and Lot (BBL) self-reported              11746 non-null  object
#  7   NYC Building Identification Number (BIN)                    11746 non-null  object
#  8   Address 1 (self-reported)                                   11746 non-null  object
#  9   Address 2                                                   11746 non-null  object
#  10  Postal Code                                                 11746 non-null  object
#  11  Street Number                                               11622 non-null  object
#  12  Street Name                                                 11624 non-null  object
#  13  Borough                                                     11628 non-null  object
#  14  DOF Gross Floor Area                                        11628 non-null  float64
#  15  Primary Property Type - Self Selected                       11746 non-null  object
#  16  List of All Property Use Types at Property                  11746 non-null  object
#  17  Largest Property Use Type                                   11746 non-null  object
#  18  Largest Property Use Type - Gross Floor Area (ft²)          11746 non-null  object
#  19  2nd Largest Property Use Type                               11746 non-null  object
#  20  2nd Largest Property Use - Gross Floor Area (ft²)           11746 non-null  object
#  21  3rd Largest Property Use Type                               11746 non-null  object
#  22  3rd Largest Property Use Type - Gross Floor Area (ft²)      11746 non-null  object
#  23  Year Built                                                  11746 non-null  int64
#  24  Number of Buildings - Self-reported                         11746 non-null  int64
#  25  Occupancy                                                   11746 non-null  int64
#  26  Metered Areas (Energy)                                      11746 non-null  object
#  27  Metered Areas  (Water)                                      11746 non-null  object
#  28  ENERGY STAR Score                                           11746 non-null  object
#  29  Site EUI (kBtu/ft²)                                         11746 non-null  object
#  30  Weather Normalized Site EUI (kBtu/ft²)                      11746 non-null  object
#  31  Weather Normalized Site Electricity Intensity (kWh/ft²)     11746 non-null  object
#  32  Weather Normalized Site Natural Gas Intensity (therms/ft²)  11746 non-null  object
#  33  Weather Normalized Source EUI (kBtu/ft²)                    11746 non-null  object
#  34  Fuel Oil #1 Use (kBtu)                                      11746 non-null  object
#  35  Fuel Oil #2 Use (kBtu)                                      11746 non-null  object
#  36  Fuel Oil #4 Use (kBtu)                                      11746 non-null  object
#  37  Fuel Oil #5 & 6 Use (kBtu)                                  11746 non-null  object
#  38  Diesel #2 Use (kBtu)                                        11746 non-null  object
#  39  District Steam Use (kBtu)                                   11746 non-null  object
#  40  Natural Gas Use (kBtu)                                      11746 non-null  object
#  41  Weather Normalized Site Natural Gas Use (therms)            11746 non-null  object
#  42  Electricity Use - Grid Purchase (kBtu)                      11746 non-null  object
#  43  Weather Normalized Site Electricity (kWh)                   11746 non-null  object
#  44  Total GHG Emissions (Metric Tons CO2e)                      11746 non-null  object
#  45  Direct GHG Emissions (Metric Tons CO2e)                     11746 non-null  object
#  46  Indirect GHG Emissions (Metric Tons CO2e)                   11746 non-null  object
#  47  Property GFA - Self-Reported (ft²)                          11746 non-null  int64
#  48  Water Use (All Water Sources) (kgal)                        11746 non-null  object
#  49  Water Intensity (All Water Sources) (gal/ft²)               11746 non-null  object
#  50  Source EUI (kBtu/ft²)                                       11746 non-null  object
#  51  Release Date                                                11746 non-null  object
#  52  Water Required?                                             11628 non-null  object
#  53  DOF Benchmarking Submission Status                          11716 non-null  object
#  54  Latitude                                                    9483 non-null   float64
#  55  Longitude                                                   9483 non-null   float64
#  56  Community Board                                             9483 non-null   float64
#  57  Council District                                            9483 non-null   float64
#  58  Census Tract                                                9483 non-null   float64
#  59  NTA                                                         9483 non-null   object
# dtypes: float64(6), int64(6), object(48)
# memory usage: 5.4+ MB

# %% [markdown]
# #### We will do a little preprocessing on the Data

# %%
df.replace("Not Available", np.nan, inplace=True)      
#now we know the exact amount of Nan values

# %%
df.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# 2                                   1-02138-0030
# 3                                   1-02139-0001
# 4                                   1-02139-0085
#
#             NYC Building Identification Number (BIN)  \
# 0                                            1037549
# 1  1084198; 1084387;1084385; 1084386; 1084388; 10...
# 2                                            1063380
# 3                                   1087281; 1076746
# 4                                            1063403
#
#   Address 1 (self-reported)                Address 2  ...  \
# 0  201/205  East  42nd  st.                      NaN  ...
# 1          622 168th Street                      NaN  ...
# 2             3975 Broadway                      NaN  ...
# 3   161 Fort Washington Ave  177 Fort Washington Ave  ...
# 4     710 West 168th Street                      NaN  ...
#
#   Source EUI (kBtu/ft²)            Release Date Water Required?  \
# 0                 619.4  05/01/2017 05:32:03 PM              No
# 1                 404.3  04/27/2017 11:23:27 AM              No
# 2                   NaN  04/27/2017 11:23:27 AM              No
# 3                   NaN  04/27/2017 11:23:27 AM              No
# 4                   NaN  04/27/2017 11:23:27 AM              No
#
#   DOF Benchmarking Submission Status   Latitude  Longitude Community Board  \
# 0                      In Compliance  40.750791 -73.973963             6.0
# 1                      In Compliance  40.841402 -73.942568            12.0
# 2                      In Compliance  40.840427 -73.940249            12.0
# 3                      In Compliance  40.840746 -73.942854            12.0
# 4                      In Compliance  40.841559 -73.942528            12.0
#
#   Council District Census Tract  \
# 0              4.0         88.0
# 1             10.0        251.0
# 2             10.0        251.0
# 3             10.0        255.0
# 4             10.0        255.0
#
#                                                  NTA
# 0  Turtle Bay-East Midtown                       ...
# 1  Washington Heights South                      ...
# 2  Washington Heights South                      ...
# 3  Washington Heights South                      ...
# 4  Washington Heights South                      ...
#
# [5 rows x 60 columns]

# %%
missing_values_count = df.isnull().sum()
print(missing_values_count)
# Out:
# Order                                                             0
# Property Id                                                       0
# Property Name                                                     0
# Parent Property Id                                                0
# Parent Property Name                                              0
# BBL - 10 digits                                                  11
# NYC Borough, Block and Lot (BBL) self-reported                   11
# NYC Building Identification Number (BIN)                        162
# Address 1 (self-reported)                                         0
# Address 2                                                     11539
# Postal Code                                                       0
# Street Number                                                   124
# Street Name                                                     122
# Borough                                                         118
# DOF Gross Floor Area                                            118
# Primary Property Type - Self Selected                             0
# List of All Property Use Types at Property                        0
# Largest Property Use Type                                         2
# Largest Property Use Type - Gross Floor Area (ft²)                2
# 2nd Largest Property Use Type                                  8005
# 2nd Largest Property Use - Gross Floor Area (ft²)              8005
# 3rd Largest Property Use Type                                 10262
# 3rd Largest Property Use Type - Gross Floor Area (ft²)        10262
# Year Built                                                        0
# Number of Buildings - Self-reported                               0
# Occupancy                                                         0
# Metered Areas (Energy)                                           57
# Metered Areas  (Water)                                         4609
# ENERGY STAR Score                                              2104
# Site EUI (kBtu/ft²)                                             163
# Weather Normalized Site EUI (kBtu/ft²)                         1465
# Weather Normalized Site Electricity Intensity (kWh/ft²)         787
# Weather Normalized Site Natural Gas Intensity (therms/ft²)     1963
# Weather Normalized Source EUI (kBtu/ft²)                       1465
# Fuel Oil #1 Use (kBtu)                                        11737
# Fuel Oil #2 Use (kBtu)                                         9165
# Fuel Oil #4 Use (kBtu)                                        10425
# Fuel Oil #5 & 6 Use (kBtu)                                    11152
# Diesel #2 Use (kBtu)                                          11730
# District Steam Use (kBtu)                                     10810
# Natural Gas Use (kBtu)                                         1442
# Weather Normalized Site Natural Gas Use (therms)               1962
# Electricity Use - Grid Purchase (kBtu)                          244
# Weather Normalized Site Electricity (kWh)                       786
# Total GHG Emissions (Metric Tons CO2e)                           74
# Direct GHG Emissions (Metric Tons CO2e)                          83
# Indirect GHG Emissions (Metric Tons CO2e)                        65
# Property GFA - Self-Reported (ft²)                                0
# Water Use (All Water Sources) (kgal)                           3984
# Water Intensity (All Water Sources) (gal/ft²)                  3984
# Source EUI (kBtu/ft²)                                           163
# Release Date                                                      0
# Water Required?                                                 118
# DOF Benchmarking Submission Status                               30
# Latitude                                                       2263
# Longitude                                                      2263
# Community Board                                                2263
# Council District                                               2263
# Census Tract                                                   2263
# NTA                                                            2263
# dtype: int64

# %%
df['ENERGY STAR Score'] = df['ENERGY STAR Score'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11746 non-null  int64
#  1   Property Id                                                 11746 non-null  int64
#  2   Property Name                                               11746 non-null  object
#  3   Parent Property Id                                          11746 non-null  object
#  4   Parent Property Name                                        11746 non-null  object
#  5   BBL - 10 digits                                             11735 non-null  object
#  6   NYC Borough, Block and Lot (BBL) self-reported              11735 non-null  object
#  7   NYC Building Identification Number (BIN)                    11584 non-null  object
#  8   Address 1 (self-reported)                                   11746 non-null  object
#  9   Address 2                                                   207 non-null    object
#  10  Postal Code                                                 11746 non-null  object
#  11  Street Number                                               11622 non-null  object
#  12  Street Name                                                 11624 non-null  object
#  13  Borough                                                     11628 non-null  object
#  14  DOF Gross Floor Area                                        11628 non-null  float64
#  15  Primary Property Type - Self Selected                       11746 non-null  object
#  16  List of All Property Use Types at Property                  11746 non-null  object
#  17  Largest Property Use Type                                   11744 non-null  object
#  18  Largest Property Use Type - Gross Floor Area (ft²)          11744 non-null  object
#  19  2nd Largest Property Use Type                               3741 non-null   object
#  20  2nd Largest Property Use - Gross Floor Area (ft²)           3741 non-null   object
#  21  3rd Largest Property Use Type                               1484 non-null   object
#  22  3rd Largest Property Use Type - Gross Floor Area (ft²)      1484 non-null   object
#  23  Year Built                                                  11746 non-null  int64
#  24  Number of Buildings - Self-reported                         11746 non-null  int64
#  25  Occupancy                                                   11746 non-null  int64
#  26  Metered Areas (Energy)                                      11689 non-null  object
#  27  Metered Areas  (Water)                                      7137 non-null   object
#  28  ENERGY STAR Score                                           9642 non-null   float64
#  29  Site EUI (kBtu/ft²)                                         11583 non-null  object
#  30  Weather Normalized Site EUI (kBtu/ft²)                      10281 non-null  object
#  31  Weather Normalized Site Electricity Intensity (kWh/ft²)     10959 non-null  object
#  32  Weather Normalized Site Natural Gas Intensity (therms/ft²)  9783 non-null   object
#  33  Weather Normalized Source EUI (kBtu/ft²)                    10281 non-null  object
#  34  Fuel Oil #1 Use (kBtu)                                      9 non-null      object
#  35  Fuel Oil #2 Use (kBtu)                                      2581 non-null   object
#  36  Fuel Oil #4 Use (kBtu)                                      1321 non-null   object
#  37  Fuel Oil #5 & 6 Use (kBtu)                                  594 non-null    object
#  38  Diesel #2 Use (kBtu)                                        16 non-null     object
#  39  District Steam Use (kBtu)                                   936 non-null    object
#  40  Natural Gas Use (kBtu)                                      10304 non-null  object
#  41  Weather Normalized Site Natural Gas Use (therms)            9784 non-null   object
#  42  Electricity Use - Grid Purchase (kBtu)                      11502 non-null  object
#  43  Weather Normalized Site Electricity (kWh)                   10960 non-null  object
#  44  Total GHG Emissions (Metric Tons CO2e)                      11672 non-null  object
#  45  Direct GHG Emissions (Metric Tons CO2e)                     11663 non-null  object
#  46  Indirect GHG Emissions (Metric Tons CO2e)                   11681 non-null  object
#  47  Property GFA - Self-Reported (ft²)                          11746 non-null  int64
#  48  Water Use (All Water Sources) (kgal)                        7762 non-null   object
#  49  Water Intensity (All Water Sources) (gal/ft²)               7762 non-null   object
#  50  Source EUI (kBtu/ft²)                                       11583 non-null  object
#  51  Release Date                                                11746 non-null  object
#  52  Water Required?                                             11628 non-null  object
#  53  DOF Benchmarking Submission Status                          11716 non-null  object
#  54  Latitude                                                    9483 non-null   float64
#  55  Longitude                                                   9483 non-null   float64
#  56  Community Board                                             9483 non-null   float64
#  57  Council District                                            9483 non-null   float64
#  58  Census Tract                                                9483 non-null   float64
#  59  NTA                                                         9483 non-null   object
# dtypes: float64(7), int64(6), object(47)
# memory usage: 5.4+ MB

# %%
df[["ENERGY STAR Score"]].value_counts()
# Out:
# ENERGY STAR Score
# 100.0                649
# 1.0                  299
# 99.0                 162
# 80.0                 144
# 84.0                 142
#                     ...
# 10.0                  48
# 42.0                  47
# 12.0                  47
# 21.0                  46
# 11.0                  44
# Name: count, Length: 100, dtype: int64

# %%
df['Water Required?'] = df['Water Required?'].astype("category")

# %%
df["Water Required?"].value_counts()
# Out:
# Water Required?
# Yes    7552
# No     4076
# Name: count, dtype: int64

# %%
null_percentage=df.isnull().sum()/len(df) * 100
null_percentage
# Out:
# Order                                                          0.000000
# Property Id                                                    0.000000
# Property Name                                                  0.000000
# Parent Property Id                                             0.000000
# Parent Property Name                                           0.000000
# BBL - 10 digits                                                0.093649
# NYC Borough, Block and Lot (BBL) self-reported                 0.093649
# NYC Building Identification Number (BIN)                       1.379193
# Address 1 (self-reported)                                      0.000000
# Address 2                                                     98.237698
# Postal Code                                                    0.000000
# Street Number                                                  1.055679
# Street Name                                                    1.038651
# Borough                                                        1.004597
# DOF Gross Floor Area                                           1.004597
# Primary Property Type - Self Selected                          0.000000
# List of All Property Use Types at Property                     0.000000
# Largest Property Use Type                                      0.017027
# Largest Property Use Type - Gross Floor Area (ft²)             0.017027
# 2nd Largest Property Use Type                                 68.150860
# 2nd Largest Property Use - Gross Floor Area (ft²)             68.150860
# 3rd Largest Property Use Type                                 87.365912
# 3rd Largest Property Use Type - Gross Floor Area (ft²)        87.365912
# Year Built                                                     0.000000
# Number of Buildings - Self-reported                            0.000000
# Occupancy                                                      0.000000
# Metered Areas (Energy)                                         0.485272
# Metered Areas  (Water)                                        39.238890
# ENERGY STAR Score                                             17.912481
# Site EUI (kBtu/ft²)                                            1.387706
# Weather Normalized Site EUI (kBtu/ft²)                        12.472331
# Weather Normalized Site Electricity Intensity (kWh/ft²)        6.700153
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    16.712072
# Weather Normalized Source EUI (kBtu/ft²)                      12.472331
# Fuel Oil #1 Use (kBtu)                                        99.923378
# Fuel Oil #2 Use (kBtu)                                        78.026562
# Fuel Oil #4 Use (kBtu)                                        88.753618
# Fuel Oil #5 & 6 Use (kBtu)                                    94.942959
# Diesel #2 Use (kBtu)                                          99.863783
# District Steam Use (kBtu)                                     92.031330
# Natural Gas Use (kBtu)                                        12.276520
# Weather Normalized Site Natural Gas Use (therms)              16.703559
# Electricity Use - Grid Purchase (kBtu)                         2.077303
# Weather Normalized Site Electricity (kWh)                      6.691640
# Total GHG Emissions (Metric Tons CO2e)                         0.630002
# Direct GHG Emissions (Metric Tons CO2e)                        0.706624
# Indirect GHG Emissions (Metric Tons CO2e)                      0.553380
# Property GFA - Self-Reported (ft²)                             0.000000
# Water Use (All Water Sources) (kgal)                          33.917930
# Water Intensity (All Water Sources) (gal/ft²)                 33.917930
# Source EUI (kBtu/ft²)                                          1.387706
# Release Date                                                   0.000000
# Water Required?                                                1.004597
# DOF Benchmarking Submission Status                             0.255406
# Latitude                                                      19.266133
# Longitude                                                     19.266133
# Community Board                                               19.266133
# Council District                                              19.266133
# Census Tract                                                  19.266133
# NTA                                                           19.266133
# dtype: float64

# %%
columns_to_drop = null_percentage[null_percentage > 19].index

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 40 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11746 non-null  int64
#  1   Property Id                                                 11746 non-null  int64
#  2   Property Name                                               11746 non-null  object
#  3   Parent Property Id                                          11746 non-null  object
#  4   Parent Property Name                                        11746 non-null  object
#  5   BBL - 10 digits                                             11735 non-null  object
#  6   NYC Borough, Block and Lot (BBL) self-reported              11735 non-null  object
#  7   NYC Building Identification Number (BIN)                    11584 non-null  object
#  8   Address 1 (self-reported)                                   11746 non-null  object
#  9   Postal Code                                                 11746 non-null  object
#  10  Street Number                                               11622 non-null  object
#  11  Street Name                                                 11624 non-null  object
#  12  Borough                                                     11628 non-null  object
#  13  DOF Gross Floor Area                                        11628 non-null  float64
#  14  Primary Property Type - Self Selected                       11746 non-null  object
#  15  List of All Property Use Types at Property                  11746 non-null  object
#  16  Largest Property Use Type                                   11744 non-null  object
#  17  Largest Property Use Type - Gross Floor Area (ft²)          11744 non-null  object
#  18  Year Built                                                  11746 non-null  int64
#  19  Number of Buildings - Self-reported                         11746 non-null  int64
#  20  Occupancy                                                   11746 non-null  int64
#  21  Metered Areas (Energy)                                      11689 non-null  object
#  22  ENERGY STAR Score                                           9642 non-null   float64
#  23  Site EUI (kBtu/ft²)                                         11583 non-null  object
#  24  Weather Normalized Site EUI (kBtu/ft²)                      10281 non-null  object
#  25  Weather Normalized Site Electricity Intensity (kWh/ft²)     10959 non-null  object
#  26  Weather Normalized Site Natural Gas Intensity (therms/ft²)  9783 non-null   object
#  27  Weather Normalized Source EUI (kBtu/ft²)                    10281 non-null  object
#  28  Natural Gas Use (kBtu)                                      10304 non-null  object
#  29  Weather Normalized Site Natural Gas Use (therms)            9784 non-null   object
#  30  Electricity Use - Grid Purchase (kBtu)                      11502 non-null  object
#  31  Weather Normalized Site Electricity (kWh)                   10960 non-null  object
#  32  Total GHG Emissions (Metric Tons CO2e)                      11672 non-null  object
#  33  Direct GHG Emissions (Metric Tons CO2e)                     11663 non-null  object
#  34  Indirect GHG Emissions (Metric Tons CO2e)                   11681 non-null  object
#  35  Property GFA - Self-Reported (ft²)                          11746 non-null  int64
#  36  Source EUI (kBtu/ft²)                                       11583 non-null  object
#  37  Release Date                                                11746 non-null  object
#  38  Water Required?                                             11628 non-null  category
#  39  DOF Benchmarking Submission Status                          11716 non-null  object
# dtypes: category(1), float64(2), int64(6), object(31)
# memory usage: 3.5+ MB

# %%
df['Release Date'] = pd.to_datetime(df['Release Date']) # changing type of release date column to date time astype

df.columns
# Out:
# C:\Users\91907\AppData\Local\Temp\ipykernel_16044\1446657076.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Release Date'] = pd.to_datetime(df['Release Date']) # changing type of release date column to date time astype
# Index(['Order', 'Property Id', 'Property Name', 'Parent Property Id',
#        'Parent Property Name', 'BBL - 10 digits',
#        'NYC Borough, Block and Lot (BBL) self-reported',
#        'NYC Building Identification Number (BIN)', 'Address 1 (self-reported)',
#        'Postal Code', 'Street Number', 'Street Name', 'Borough',
#        'DOF Gross Floor Area', 'Primary Property Type - Self Selected',
#        'List of All Property Use Types at Property',
#        'Largest Property Use Type',
#        'Largest Property Use Type - Gross Floor Area (ft²)', 'Year Built',
#        'Number of Buildings - Self-reported', 'Occupancy',
#        'Metered Areas (Energy)', 'ENERGY STAR Score', 'Site EUI (kBtu/ft²)',
#        'Weather Normalized Site EUI (kBtu/ft²)',
#        'Weather Normalized Site Electricity Intensity (kWh/ft²)',
#        'Weather Normalized Site Natural Gas Intensity (therms/ft²)',
#        'Weather Normalized Source EUI (kBtu/ft²)', 'Natural Gas Use (kBtu)',
#        'Weather Normalized Site Natural Gas Use (therms)',
#        'Electricity Use - Grid Purchase (kBtu)',
#        'Weather Normalized Site Electricity (kWh)',
#        'Total GHG Emissions (Metric Tons CO2e)',
#        'Direct GHG Emissions (Metric Tons CO2e)',
#        'Indirect GHG Emissions (Metric Tons CO2e)',
#        'Property GFA - Self-Reported (ft²)', 'Source EUI (kBtu/ft²)',
#        'Release Date', 'Water Required?',
#        'DOF Benchmarking Submission Status'],
#       dtype='object')

# %%
# we also have a lot of columns that have float values and need to be converted to float dtype
features_to_convert = ["Site EUI (kBtu/ft²)",
       'Weather Normalized Site EUI (kBtu/ft²)',
       'Weather Normalized Site Electricity Intensity (kWh/ft²)',
       'Weather Normalized Site Natural Gas Intensity (therms/ft²)',
       'Weather Normalized Source EUI (kBtu/ft²)', 'Natural Gas Use (kBtu)',
       'Weather Normalized Site Natural Gas Use (therms)',
       'Electricity Use - Grid Purchase (kBtu)',
       'Weather Normalized Site Electricity (kWh)',
       'Total GHG Emissions (Metric Tons CO2e)',
       'Direct GHG Emissions (Metric Tons CO2e)',
       'Indirect GHG Emissions (Metric Tons CO2e)','Source EUI (kBtu/ft²)']

for column in features_to_convert:
    df[column] = df[column].astype(float)

# %%
df=df.drop(["Order","Property Id","Parent Property Id","Postal Code","Street Number"],axis=1)

# %%
df_complete= df.select_dtypes(include=['float64', 'int64'])

# %% [markdown]
# #### We can use this information while model training and preprocessing

# %%
null_percentage=df.isnull().sum()/len(df) * 100          # going to fill some values in columns with null values
null_percentage
# Out:
# Property Name                                                  0.000000
# Parent Property Name                                           0.000000
# BBL - 10 digits                                                0.093649
# NYC Borough, Block and Lot (BBL) self-reported                 0.093649
# NYC Building Identification Number (BIN)                       1.379193
# Address 1 (self-reported)                                      0.000000
# Street Name                                                    1.038651
# Borough                                                        1.004597
# DOF Gross Floor Area                                           1.004597
# Primary Property Type - Self Selected                          0.000000
# List of All Property Use Types at Property                     0.000000
# Largest Property Use Type                                      0.017027
# Largest Property Use Type - Gross Floor Area (ft²)             0.017027
# Year Built                                                     0.000000
# Number of Buildings - Self-reported                            0.000000
# Occupancy                                                      0.000000
# Metered Areas (Energy)                                         0.485272
# ENERGY STAR Score                                             17.912481
# Site EUI (kBtu/ft²)                                            1.387706
# Weather Normalized Site EUI (kBtu/ft²)                        12.472331
# Weather Normalized Site Electricity Intensity (kWh/ft²)        6.700153
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    16.712072
# Weather Normalized Source EUI (kBtu/ft²)                      12.472331
# Natural Gas Use (kBtu)                                        12.276520
# Weather Normalized Site Natural Gas Use (therms)              16.703559
# Electricity Use - Grid Purchase (kBtu)                         2.077303
# Weather Normalized Site Electricity (kWh)                      6.691640
# Total GHG Emissions (Metric Tons CO2e)                         0.630002
# Direct GHG Emissions (Metric Tons CO2e)                        0.706624
# Indirect GHG Emissions (Metric Tons CO2e)                      0.553380
# Property GFA - Self-Reported (ft²)                             0.000000
# Source EUI (kBtu/ft²)                                          1.387706
# Release Date                                                   0.000000
# Water Required?                                                1.004597
# DOF Benchmarking Submission Status                             0.255406
# dtype: float64

# %%
columns_to_backfill = null_percentage[null_percentage < 3].index

# %%
df[columns_to_backfill] = df[columns_to_backfill].fillna(method='bfill', axis=0)

# %%
null_percentage=df.isnull().sum()/len(df) * 100

# %%
null_percentage
# Out:
# Property Name                                                  0.000000
# Parent Property Name                                           0.000000
# BBL - 10 digits                                                0.000000
# NYC Borough, Block and Lot (BBL) self-reported                 0.000000
# NYC Building Identification Number (BIN)                       0.000000
# Address 1 (self-reported)                                      0.000000
# Street Name                                                    0.000000
# Borough                                                        0.000000
# DOF Gross Floor Area                                           0.000000
# Primary Property Type - Self Selected                          0.000000
# List of All Property Use Types at Property                     0.000000
# Largest Property Use Type                                      0.000000
# Largest Property Use Type - Gross Floor Area (ft²)             0.000000
# Year Built                                                     0.000000
# Number of Buildings - Self-reported                            0.000000
# Occupancy                                                      0.000000
# Metered Areas (Energy)                                         0.000000
# ENERGY STAR Score                                             17.912481
# Site EUI (kBtu/ft²)                                            0.000000
# Weather Normalized Site EUI (kBtu/ft²)                        12.472331
# Weather Normalized Site Electricity Intensity (kWh/ft²)        6.700153
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    16.712072
# Weather Normalized Source EUI (kBtu/ft²)                      12.472331
# Natural Gas Use (kBtu)                                        12.276520
# Weather Normalized Site Natural Gas Use (therms)              16.703559
# Electricity Use - Grid Purchase (kBtu)                         0.000000
# Weather Normalized Site Electricity (kWh)                      6.691640
# Total GHG Emissions (Metric Tons CO2e)                         0.000000
# Direct GHG Emissions (Metric Tons CO2e)                        0.000000
# Indirect GHG Emissions (Metric Tons CO2e)                      0.000000
# Property GFA - Self-Reported (ft²)                             0.000000
# Source EUI (kBtu/ft²)                                          0.000000
# Release Date                                                   0.000000
# Water Required?                                                0.000000
# DOF Benchmarking Submission Status                             0.246893
# dtype: float64

# %%
df["DOF Benchmarking Submission Status"]=df["DOF Benchmarking Submission Status"].fillna("mode")

# %%
# the below two features are similar in property and share similar data, so imputing based on that
merged_df = df[["Site EUI (kBtu/ft²)", "Weather Normalized Site EUI (kBtu/ft²)"]].copy()
merged_df.loc[merged_df["Weather Normalized Site EUI (kBtu/ft²)"].isnull(), "Weather Normalized Site EUI (kBtu/ft²)"] = merged_df.loc[merged_df["Weather Normalized Site EUI (kBtu/ft²)"].isnull(),"Site EUI (kBtu/ft²)"]

# %%
df["Weather Normalized Site EUI (kBtu/ft²)"]=merged_df["Weather Normalized Site EUI (kBtu/ft²)"]

# %%
df["Release Date"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       2017-05-01 17:32:03
# 1       2017-04-27 11:23:27
# 2       2017-04-27 11:23:27
# 3       2017-04-27 11:23:27
# 4       2017-04-27 11:23:27
#                 ...
# 11741   2017-04-26 11:20:06
# 11742   2017-04-26 11:20:06
# 11743   2017-03-23 14:51:02
# 11744   2017-04-26 11:20:06
# 11745   2017-04-27 06:37:53
# Name: Release Date, Length: 11746, dtype: datetime64[ns]>

# %%
merged_df = df[["Source EUI (kBtu/ft²)", "Weather Normalized Source EUI (kBtu/ft²)"]].copy()
merged_df.loc[merged_df["Weather Normalized Source EUI (kBtu/ft²)"].isnull(), "Weather Normalized Source EUI (kBtu/ft²)"] = merged_df.loc[merged_df["Weather Normalized Source EUI (kBtu/ft²)"].isnull(),"Source EUI (kBtu/ft²)"]
df["Weather Normalized Source EUI (kBtu/ft²)"]=merged_df["Weather Normalized Source EUI (kBtu/ft²)"]

# %%
null_percentage=df.isnull().sum()/len(df) * 100 
null_percentage
# Out:
# Property Name                                                  0.000000
# Parent Property Name                                           0.000000
# BBL - 10 digits                                                0.000000
# NYC Borough, Block and Lot (BBL) self-reported                 0.000000
# NYC Building Identification Number (BIN)                       0.000000
# Address 1 (self-reported)                                      0.000000
# Street Name                                                    0.000000
# Borough                                                        0.000000
# DOF Gross Floor Area                                           0.000000
# Primary Property Type - Self Selected                          0.000000
# List of All Property Use Types at Property                     0.000000
# Largest Property Use Type                                      0.000000
# Largest Property Use Type - Gross Floor Area (ft²)             0.000000
# Year Built                                                     0.000000
# Number of Buildings - Self-reported                            0.000000
# Occupancy                                                      0.000000
# Metered Areas (Energy)                                         0.000000
# ENERGY STAR Score                                             17.912481
# Site EUI (kBtu/ft²)                                            0.000000
# Weather Normalized Site EUI (kBtu/ft²)                         0.000000
# Weather Normalized Site Electricity Intensity (kWh/ft²)        6.700153
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    16.712072
# Weather Normalized Source EUI (kBtu/ft²)                       0.000000
# Natural Gas Use (kBtu)                                        12.276520
# Weather Normalized Site Natural Gas Use (therms)              16.703559
# Electricity Use - Grid Purchase (kBtu)                         0.000000
# Weather Normalized Site Electricity (kWh)                      6.691640
# Total GHG Emissions (Metric Tons CO2e)                         0.000000
# Direct GHG Emissions (Metric Tons CO2e)                        0.000000
# Indirect GHG Emissions (Metric Tons CO2e)                      0.000000
# Property GFA - Self-Reported (ft²)                             0.000000
# Source EUI (kBtu/ft²)                                          0.000000
# Release Date                                                   0.000000
# Water Required?                                                0.000000
# DOF Benchmarking Submission Status                             0.000000
# dtype: float64

# %%
df[["Weather Normalized Site Electricity Intensity (kWh/ft²)"]].describe()
# Out:
#        Weather Normalized Site Electricity Intensity (kWh/ft²)
# count                                       10959.000000
# mean                                           11.072643
# std                                           127.733868
# min                                             0.000000
# 25%                                             3.800000
# 50%                                             5.300000
# 75%                                             9.200000
# max                                          6259.400000

# %%
df[["Weather Normalized Site Electricity Intensity (kWh/ft²)"]].value_counts()
# Out:
# Weather Normalized Site Electricity Intensity (kWh/ft²)
# 4.0                                                        230
# 4.1                                                        221
# 3.7                                                        218
# 4.5                                                        218
# 3.8                                                        217
#                                                           ...
# 39.1                                                         1
# 38.9                                                         1
# 38.8                                                         1
# 38.4                                                         1
# 6259.4                                                       1
# Name: count, Length: 440, dtype: int64

# %% [markdown]
# ## EDA

# %%
df_complete= df.select_dtypes(include=['float64', 'int64'])

# %%
correlation_matrix = df_complete.corr()

correlation_with_target = correlation_matrix['ENERGY STAR Score']

# %%
print("Correlation of all features with 'Energy Star Score':")
print(correlation_with_target)
# Out:
# Correlation of all features with 'Energy Star Score':
# DOF Gross Floor Area                                          0.005107
# Year Built                                                   -0.118181
# Number of Buildings - Self-reported                          -0.020564
# Occupancy                                                    -0.031116
# ENERGY STAR Score                                             1.000000
# Site EUI (kBtu/ft²)                                          -0.036123
# Weather Normalized Site EUI (kBtu/ft²)                       -0.035460
# Weather Normalized Site Electricity Intensity (kWh/ft²)      -0.067762
# Weather Normalized Site Natural Gas Intensity (therms/ft²)   -0.023008
# Weather Normalized Source EUI (kBtu/ft²)                     -0.041785
# Natural Gas Use (kBtu)                                       -0.026170
# Weather Normalized Site Natural Gas Use (therms)             -0.026215
# Electricity Use - Grid Purchase (kBtu)                       -0.064313
# Weather Normalized Site Electricity (kWh)                    -0.065789
# Total GHG Emissions (Metric Tons CO2e)                       -0.047932
# Direct GHG Emissions (Metric Tons CO2e)                      -0.026344
# Indirect GHG Emissions (Metric Tons CO2e)                    -0.040297
# Property GFA - Self-Reported (ft²)                            0.016800
# Source EUI (kBtu/ft²)                                        -0.042873
# Name: ENERGY STAR Score, dtype: float64

# %%
plt.figure(figsize=(15,20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',)
# Out:
# <Axes: >

# %%
selected_features = [ 'Site EUI (kBtu/ft²)', 'Weather Normalized Source EUI (kBtu/ft²)', 'ENERGY STAR Score']
sns.pairplot(df[selected_features])
plt.show()
# Out:
# C:\Users\91907\anaconda3.1\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.scatter(df['Year Built'], df['ENERGY STAR Score'])
plt.xlabel('Year Built')
plt.ylabel('Energy Star Score')
plt.title('Year Built vs. ENERGY STAR Score')
plt.show()

# %%
plt.hist(df[df['ENERGY STAR Score'] < 50]['Number of Buildings - Self-reported'], alpha=0.5, label='<50 ENERGY STAR Score')
plt.hist(df[df['ENERGY STAR Score'] >= 50]['Number of Buildings - Self-reported'], alpha=0.5, label='>=50 ENERGY STAR Score')
plt.xlabel('Number of Buildings - Self-reported')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Buildings by Energy Star Score')
plt.legend()
plt.show()

# %%
df['ENERGY STAR Score Quartile'] = pd.qcut(df['ENERGY STAR Score'], q=4)
plt.figure(figsize=(8, 6))
sns.boxplot(x='Occupancy', y='ENERGY STAR Score Quartile', data=df)
plt.xlabel('Occupancy')
plt.ylabel('ENERGY STAR Score  Quartile')
plt.title('Occupancy vs. ENERGY STAR Score Quartile')
plt.show()

# %%
sns.violinplot(x='Borough', y='ENERGY STAR Score', data=df)
plt.xlabel('Borough')
plt.ylabel('Energy Star Score')
plt.title('Violin Plot of Energy Star Score by Borough')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(df,x="Weather Normalized Site Electricity Intensity (kWh/ft²)")
# Out:
# <Axes: xlabel='Weather Normalized Site Electricity Intensity (kWh/ft²)'>

# %% [markdown]
# ## Random forest
# using random forest we can find the most important features and least important features

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error

# %%
X = df_complete.drop(columns=['ENERGY STAR Score'])  # Features
y = df_complete['ENERGY STAR Score']

# %%
imputer = SimpleImputer(strategy='median')
y_imputed = imputer.fit_transform(y.values.reshape(-1, 1))
y_imputed = pd.Series(y_imputed.flatten(), index=y.index)
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)


X_imputed_df = pd.DataFrame(X_imputed, columns=X.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y_imputed, test_size=0.2, random_state=22)

# %%
rf_model = RandomForestRegressor(random_state=22)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=22)

# %%
y_pred = rf_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 324.03610246010635

# %%
feature_importance = rf_model.feature_importances_

# %%
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print or visualize the feature importance
print(feature_importance_df)
# Out:
#                                               Feature  Importance
# 17                              Source EUI (kBtu/ft²)    0.245200
# 8            Weather Normalized Source EUI (kBtu/ft²)    0.239492
# 4                                 Site EUI (kBtu/ft²)    0.120964
# 1                                          Year Built    0.059645
# 5              Weather Normalized Site EUI (kBtu/ft²)    0.052576
# 6   Weather Normalized Site Electricity Intensity ...    0.036838
# 0                                DOF Gross Floor Area    0.030694
# 14            Direct GHG Emissions (Metric Tons CO2e)    0.027667
# 13             Total GHG Emissions (Metric Tons CO2e)    0.027027
# 9                              Natural Gas Use (kBtu)    0.025075
# 16                 Property GFA - Self-Reported (ft²)    0.024752
# 11             Electricity Use - Grid Purchase (kBtu)    0.024621
# 10   Weather Normalized Site Natural Gas Use (therms)    0.024088
# 15          Indirect GHG Emissions (Metric Tons CO2e)    0.022220
# 12          Weather Normalized Site Electricity (kWh)    0.019913
# 7   Weather Normalized Site Natural Gas Intensity ...    0.008956
# 3                                           Occupancy    0.006389
# 2                 Number of Buildings - Self-reported    0.003882

# %% [markdown]
# ### now lets do another model training by dropping the null values instead of imputing

# %%
df_complete_dropna = df_complete.dropna(subset=['ENERGY STAR Score'])

# %%
X_dropna = df_complete_dropna.drop(columns=['ENERGY STAR Score']) 
y_dropna = df_complete_dropna['ENERGY STAR Score']

imputer = SimpleImputer(strategy='median')
X_dropna_imputed = imputer.fit_transform(X_dropna)


X_dropna_imputed_df = pd.DataFrame(X_dropna_imputed, columns=X_dropna.columns)

# %%
X_train_dropna, X_test_dropna, y_train_dropna, y_test_dropna = train_test_split(X_dropna_imputed_df, y_dropna, test_size=0.2, random_state=2)

# %%
rf_model_dropna = RandomForestRegressor(random_state=2)
rf_model_dropna.fit(X_train_dropna, y_train_dropna)
# Out:
# RandomForestRegressor(random_state=2)

# %%
y_pred_dropna_imputed = rf_model_dropna.predict(X_test_dropna)
mse_dropna_imputed = mean_squared_error(y_test_dropna, y_pred_dropna_imputed)
print("Mean Squared Error (after dropping null values and imputing missing values):", mse_dropna_imputed)
# Out:
# Mean Squared Error (after dropping null values and imputing missing values): 280.78786340072577

# %%
feature_importance_dropna_imputed = rf_model_dropna.feature_importances_

# %%
feature_importance_dropna_imputed_df = pd.DataFrame({'Feature': X_dropna_imputed_df.columns, 'Importance': feature_importance_dropna_imputed})
feature_importance_dropna_imputed_df = feature_importance_dropna_imputed_df.sort_values(by='Importance', ascending=False)

# %%
feature_importance_dropna_imputed_df
# Out:
#                                               Feature  Importance
# 17                              Source EUI (kBtu/ft²)    0.389880
# 8            Weather Normalized Source EUI (kBtu/ft²)    0.203297
# 4                                 Site EUI (kBtu/ft²)    0.121948
# 1                                          Year Built    0.047793
# 5              Weather Normalized Site EUI (kBtu/ft²)    0.047441
# 6   Weather Normalized Site Electricity Intensity ...    0.025144
# 0                                DOF Gross Floor Area    0.018696
# 9                              Natural Gas Use (kBtu)    0.018179
# 11             Electricity Use - Grid Purchase (kBtu)    0.017940
# 14            Direct GHG Emissions (Metric Tons CO2e)    0.017072
# 10   Weather Normalized Site Natural Gas Use (therms)    0.016988
# 13             Total GHG Emissions (Metric Tons CO2e)    0.016417
# 15          Indirect GHG Emissions (Metric Tons CO2e)    0.016299
# 16                 Property GFA - Self-Reported (ft²)    0.015623
# 12          Weather Normalized Site Electricity (kWh)    0.014790
# 7   Weather Normalized Site Natural Gas Intensity ...    0.006457
# 3                                           Occupancy    0.003450
# 2                 Number of Buildings - Self-reported    0.002587

# %%
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='blue', label='Old Model')
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance - Old Model')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_dropna_imputed_df['Feature'], feature_importance_dropna_imputed_df['Importance'], color='green', label='New Model')
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance - New Model')
plt.legend()
plt.show()

# %%
null_percentage=df_complete.isnull().sum()/len(df) * 100 
null_percentage
# Out:
# DOF Gross Floor Area                                           0.000000
# Year Built                                                     0.000000
# Number of Buildings - Self-reported                            0.000000
# Occupancy                                                      0.000000
# ENERGY STAR Score                                             17.912481
# Site EUI (kBtu/ft²)                                            0.000000
# Weather Normalized Site EUI (kBtu/ft²)                         0.000000
# Weather Normalized Site Electricity Intensity (kWh/ft²)        6.700153
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    16.712072
# Weather Normalized Source EUI (kBtu/ft²)                       0.000000
# Natural Gas Use (kBtu)                                        12.276520
# Weather Normalized Site Natural Gas Use (therms)              16.703559
# Electricity Use - Grid Purchase (kBtu)                         0.000000
# Weather Normalized Site Electricity (kWh)                      6.691640
# Total GHG Emissions (Metric Tons CO2e)                         0.000000
# Direct GHG Emissions (Metric Tons CO2e)                        0.000000
# Indirect GHG Emissions (Metric Tons CO2e)                      0.000000
# Property GFA - Self-Reported (ft²)                             0.000000
# Source EUI (kBtu/ft²)                                          0.000000
# dtype: float64

# %%
#using this feature importance info we can drop certain columns
#

# %%
sns.histplot(df["Occupancy"])
# Out:
# <Axes: xlabel='Occupancy', ylabel='Count'>

# %%
df.drop(["Occupancy","Weather Normalized Site Natural Gas Intensity (therms/ft²)","Number of Buildings - Self-reported"],axis=1,inplace=True)

# %%
null_percentage=df.isnull().sum()/len(df) * 100 
null_percentage
# Out:
# Property Name                                               0.000000
# Parent Property Name                                        0.000000
# BBL - 10 digits                                             0.000000
# NYC Borough, Block and Lot (BBL) self-reported              0.000000
# NYC Building Identification Number (BIN)                    0.000000
# Address 1 (self-reported)                                   0.000000
# Street Name                                                 0.000000
# Borough                                                     0.000000
# DOF Gross Floor Area                                        0.000000
# Primary Property Type - Self Selected                       0.000000
# List of All Property Use Types at Property                  0.000000
# Largest Property Use Type                                   0.000000
# Largest Property Use Type - Gross Floor Area (ft²)          0.000000
# Year Built                                                  0.000000
# Metered Areas (Energy)                                      0.000000
# ENERGY STAR Score                                          17.912481
# Site EUI (kBtu/ft²)                                         0.000000
# Weather Normalized Site EUI (kBtu/ft²)                      0.000000
# Weather Normalized Site Electricity Intensity (kWh/ft²)     6.700153
# Weather Normalized Source EUI (kBtu/ft²)                    0.000000
# Natural Gas Use (kBtu)                                     12.276520
# Weather Normalized Site Natural Gas Use (therms)           16.703559
# Electricity Use - Grid Purchase (kBtu)                      0.000000
# Weather Normalized Site Electricity (kWh)                   6.691640
# Total GHG Emissions (Metric Tons CO2e)                      0.000000
# Direct GHG Emissions (Metric Tons CO2e)                     0.000000
# Indirect GHG Emissions (Metric Tons CO2e)                   0.000000
# Property GFA - Self-Reported (ft²)                          0.000000
# Source EUI (kBtu/ft²)                                       0.000000
# Release Date                                                0.000000
# Water Required?                                             0.000000
# DOF Benchmarking Submission Status                          0.000000
# dtype: float64

# %%
sns.jointplot(df,x="Natural Gas Use (kBtu)",y="ENERGY STAR Score")

# %%
df["Water Required?"].value_counts()
# Out:
# Water Required?
# Yes    7611
# No     4135
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['Water Required?'], drop_first=True,dtype=int)

# %%
df["Water Required?_Yes"].value_counts()
# Out:
# Water Required?_Yes
# 1    7611
# 0    4135
# Name: count, dtype: int64

# %%
# we can drop the Release Date column as it is just the date of submission which is not an important column for training
df.drop(["Release Date"],axis=1,inplace=True)

# %%
df['Water Required?_Yes'] = df['Water Required?_Yes'].astype('category')

# %%
df["DOF Benchmarking Submission Status"].value_counts()# we can drop this column as well has it is showing imbalance in data
df.drop(["DOF Benchmarking Submission Status"],axis=1,inplace=True)

# %%
df['BBL - 10 digits'].value_counts()
# Out:
# BBL - 10 digits
# 1019730001    26
# 4067920600    14
# 4067900001    13
# 1018860001    10
# 3019200001     8
#               ..
# 1014880045     1
# 1014900001     1
# 1014900028     1
# 1014900122     1
# 3019600022     1
# Name: count, Length: 11580, dtype: int64

# %%
df['BBL - 10 digits'].unique # dropping this column as well
# Out:
# <bound method Series.unique of 0         1013160001
# 1         1021380040
# 2         1021380030
# 3         1021390001
# 4         1021390085
#             ...
# 11741     3002380026
# 11742     3002640017
# 11743    3009870001​
# 11744     3010720040
# 11745     3019600022
# Name: BBL - 10 digits, Length: 11746, dtype: object>

# %%
df.drop(["BBL - 10 digits"],axis=1,inplace= True)

# %%
df['NYC Borough, Block and Lot (BBL) self-reported'].value_counts()
# Out:
# NYC Borough, Block and Lot (BBL) self-reported
# 1019730001        26
# 4-06792-0600      14
# 4-06790-0001      13
# 1018860001        10
# 3-01920-0001       8
#                   ..
# 1-01488-0045       1
# 1-01490-0001       1
# 1-01490-0028       1
# 1-01490-0122       1
# 3-01960-0022\t     1
# Name: count, Length: 11581, dtype: int64

# %%
df.drop(["NYC Borough, Block and Lot (BBL) self-reported"],axis=1,inplace= True)

# %%
df.drop(["Address 1 (self-reported)","Street Name"],axis=1,inplace=True)

# %%
df['Property Name'].value_counts()
# Out:
# Property Name
# Clinton West Condominium           2
# Main Hospital                      2
# Jetro Cash && Carry                2
# East Building                      2
# Fairchild                          2
#                                   ..
# E61                                1
# Lawrence - 300 East 62nd Street    1
# AKAM - 350 East 62nd Street        1
# 301 E 62 St.                       1
# Tryad: 420 Clinton Ave             1
# Name: count, Length: 11740, dtype: int64

# %%
df['Property Name'].describe()
# Out:
# count                        11746
# unique                       11740
# top       Clinton West Condominium
# freq                             2
# Name: Property Name, dtype: object

# %%
df['Parent Property Name'].value_counts()
# Out:
# Parent Property Name
# Not Applicable: Standalone Property       11324
# Columbia University (morningside)            57
# New York University: Washington Square       33
# Original Campus                              20
# Second Housing Company Inc                   13
#                                           ...
# Deepdale Corp 2 Cluster F                     1
# Deepdale Corp 3 Cluster J                     1
# Deepdale Corp 3 Cluster G                     1
# Deepdale Corp 3 Cluster H                     1
# Beech Hills Corp 1 Site 6                     1
# Name: count, Length: 103, dtype: int64

# %%
df['Parent Property Name'].describe()
# Out:
# count                                   11746
# unique                                    103
# top       Not Applicable: Standalone Property
# freq                                    11324
# Name: Parent Property Name, dtype: object

# %%
df["NYC Building Identification Number (BIN)"].value_counts()
# Out:
# NYC Building Identification Number (BIN)
# 4455438    14
# 4455379    13
# 4451548     8
# 4451568     6
# 2008816     5
#            ..
# 1045849     1
# 1045901     1
# 1045891     1
# 1081243     1
# 3055969     1
# Name: count, Length: 11507, dtype: int64

# %%
df["NYC Building Identification Number (BIN)"].describe()
# Out:
# count       11746
# unique      11507
# top       4455438
# freq           14
# Name: NYC Building Identification Number (BIN), dtype: object

# %%
df.Borough.value_counts() # can convert this to category
# Out:
# Borough
# Manhattan        5246
# Brooklyn         2287
# Queens           2101
# Bronx            1950
# Staten Island     162
# Name: count, dtype: int64

# %%
df['Borough'] = df['Borough'].astype('category')

# %%
label_encoder = LabelEncoder()

# %%
df['Borough_encoded'] = label_encoder.fit_transform(df['Borough'])


print(df[['Borough', 'Borough_encoded']].head())
# Out:
#      Borough  Borough_encoded
# 0  Manhattan                2
# 1  Manhattan                2
# 2  Manhattan                2
# 3  Manhattan                2
# 4  Manhattan                2

# %%
sns.histplot(df["Borough"])
# Out:
# <Axes: xlabel='Borough', ylabel='Count'>

# %%
df.drop(["Borough"],axis=1,inplace=True)

# %%
df.Borough_encoded.value_counts()
# Out:
# Borough_encoded
# 2    5246
# 1    2287
# 3    2101
# 0    1950
# 4     162
# Name: count, dtype: int64

# %%
df[["Property Name","Parent Property Name"]].describe()
# Out:
#                    Property Name                 Parent Property Name
# count                      11746                                11746
# unique                     11740                                  103
# top     Clinton West Condominium  Not Applicable: Standalone Property
# freq                           2                                11324

# %%
df.drop(["Property Name","Parent Property Name"],axis=1,inplace=True) # these columns are not important for model prediction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 24 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   NYC Building Identification Number (BIN)                 11746 non-null  object
#  1   DOF Gross Floor Area                                     11746 non-null  float64
#  2   Primary Property Type - Self Selected                    11746 non-null  object
#  3   List of All Property Use Types at Property               11746 non-null  object
#  4   Largest Property Use Type                                11746 non-null  object
#  5   Largest Property Use Type - Gross Floor Area (ft²)       11746 non-null  object
#  6   Year Built                                               11746 non-null  int64
#  7   Metered Areas (Energy)                                   11746 non-null  object
#  8   ENERGY STAR Score                                        9642 non-null   float64
#  9   Site EUI (kBtu/ft²)                                      11746 non-null  float64
#  10  Weather Normalized Site EUI (kBtu/ft²)                   11746 non-null  float64
#  11  Weather Normalized Site Electricity Intensity (kWh/ft²)  10959 non-null  float64
#  12  Weather Normalized Source EUI (kBtu/ft²)                 11746 non-null  float64
#  13  Natural Gas Use (kBtu)                                   10304 non-null  float64
#  14  Weather Normalized Site Natural Gas Use (therms)         9784 non-null   float64
#  15  Electricity Use - Grid Purchase (kBtu)                   11746 non-null  float64
#  16  Weather Normalized Site Electricity (kWh)                10960 non-null  float64
#  17  Total GHG Emissions (Metric Tons CO2e)                   11746 non-null  float64
#  18  Direct GHG Emissions (Metric Tons CO2e)                  11746 non-null  float64
#  19  Indirect GHG Emissions (Metric Tons CO2e)                11746 non-null  float64
#  20  Property GFA - Self-Reported (ft²)                       11746 non-null  int64
#  21  Source EUI (kBtu/ft²)                                    11746 non-null  float64
#  22  Water Required?_Yes                                      11746 non-null  category
#  23  Borough_encoded                                          11746 non-null  int32
# dtypes: category(1), float64(14), int32(1), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
df.drop(["NYC Building Identification Number (BIN)"],axis=1,inplace=True)

# %% [markdown]
# ### Treating outliers

# %%
df_complete= df.select_dtypes(include=['float64', 'int64'])
df_complete=df_complete.drop(["ENERGY STAR Score"],axis=1)

# %%
from scipy.stats import zscore

# %%
z_scores = df_complete.apply(zscore)

# %%
threshold = 3

# Identify outliers using z-score
outliers = df[(z_scores > threshold).any(axis=1)]

# %%
outliers_per_column = {}

for column in z_scores.columns:
    outliers_per_column[column] = df[(z_scores[column] > threshold) | (z_scores[column] < -threshold)]


for column, outliers in outliers_per_column.items():
    print("Column '{}' has {} outliers.".format(column, len(outliers)))
# Out:
# Column 'DOF Gross Floor Area' has 147 outliers.
# Column 'Year Built' has 19 outliers.
# Column 'Site EUI (kBtu/ft²)' has 17 outliers.
# Column 'Weather Normalized Site EUI (kBtu/ft²)' has 18 outliers.
# Column 'Weather Normalized Site Electricity Intensity (kWh/ft²)' has 0 outliers.
# Column 'Weather Normalized Source EUI (kBtu/ft²)' has 23 outliers.
# Column 'Natural Gas Use (kBtu)' has 0 outliers.
# Column 'Weather Normalized Site Natural Gas Use (therms)' has 0 outliers.
# Column 'Electricity Use - Grid Purchase (kBtu)' has 60 outliers.
# Column 'Weather Normalized Site Electricity (kWh)' has 0 outliers.
# Column 'Total GHG Emissions (Metric Tons CO2e)' has 9 outliers.
# Column 'Direct GHG Emissions (Metric Tons CO2e)' has 2 outliers.
# Column 'Indirect GHG Emissions (Metric Tons CO2e)' has 16 outliers.
# Column 'Property GFA - Self-Reported (ft²)' has 134 outliers.
# Column 'Source EUI (kBtu/ft²)' has 23 outliers.

# %%
sns.boxplot(df["DOF Gross Floor Area"]) # Treating outliers
# Out:
# <Axes: >

# %%
# converting DOF Gross floor area to a categorical column based on area to low,medium and high
bin_edges = [0, 80000, 120000, 1000000, float('inf')]  


bin_labels = ['Small', 'Medium', 'Large', 'Very Large']


df['DOF Gross Floor Area Category'] = pd.cut(df['DOF Gross Floor Area'], bins=bin_edges, labels=bin_labels)


df.head()
# Out:
#    DOF Gross Floor Area  Primary Property Type - Self Selected  \
# 0              289356.0                                 Office
# 1             3693539.0  Hospital (General Medical & Surgical)
# 2              152765.0  Hospital (General Medical & Surgical)
# 3              891040.0  Hospital (General Medical & Surgical)
# 4              211400.0  Hospital (General Medical & Surgical)
#
#   List of All Property Use Types at Property  \
# 0                                     Office
# 1      Hospital (General Medical & Surgical)
# 2      Hospital (General Medical & Surgical)
# 3      Hospital (General Medical & Surgical)
# 4      Hospital (General Medical & Surgical)
#
#                Largest Property Use Type  \
# 0                                 Office
# 1  Hospital (General Medical & Surgical)
# 2  Hospital (General Medical & Surgical)
# 3  Hospital (General Medical & Surgical)
# 4  Hospital (General Medical & Surgical)
#
#   Largest Property Use Type - Gross Floor Area (ft²)  Year Built  \
# 0                                             293447        1963
# 1                                            3889181        1969
# 2                                             231342        1924
# 3                                            1305748        1971
# 4                                             179694        1932
#
#   Metered Areas (Energy)  ENERGY STAR Score  Site EUI (kBtu/ft²)  \
# 0         Whole Building                NaN                305.6
# 1         Whole Building               55.0                229.8
# 2         Whole Building                NaN                359.9
# 3         Whole Building                NaN                359.9
# 4         Whole Building                NaN                359.9
#
#    Weather Normalized Site EUI (kBtu/ft²)  ...  \
# 0                                   303.1  ...
# 1                                   228.8  ...
# 2                                   359.9  ...
# 3                                   359.9  ...
# 4                                   359.9  ...
#
#    Electricity Use - Grid Purchase (kBtu)  \
# 0                              38139374.2
# 1                             332365924.0
# 2                              86335350.5
# 3                              86335350.5
# 4                              86335350.5
#
#    Weather Normalized Site Electricity (kWh)  \
# 0                                 11082770.5
# 1                                 96261312.1
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Total GHG Emissions (Metric Tons CO2e)  \
# 0                                  6962.2
# 1                                 55870.4
# 2                                     0.0
# 3                                     0.0
# 4                                     0.0
#
#    Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                      0.0
# 1                                  51016.4
# 2                                      0.0
# 3                                      0.0
# 4                                      0.0
#
#    Indirect GHG Emissions (Metric Tons CO2e)  \
# 0                                     6962.2
# 1                                     4854.1
# 2                                        0.0
# 3                                        0.0
# 4                                        0.0
#
#    Property GFA - Self-Reported (ft²)  Source EUI (kBtu/ft²)  \
# 0                              762051                  619.4
# 1                             3889181                  404.3
# 2                              231342                  414.2
# 3                             1305748                  414.2
# 4                              179694                  414.2
#
#    Water Required?_Yes  Borough_encoded  DOF Gross Floor Area Category
# 0                    0                2                          Large
# 1                    0                2                     Very Large
# 2                    0                2                          Large
# 3                    0                2                          Large
# 4                    0                2                          Large
#
# [5 rows x 24 columns]

# %%
print(df[["DOF Gross Floor Area Category"]].value_counts())
# Out:
# DOF Gross Floor Area Category
# Small                            4802
# Large                            4173
# Medium                           2575
# Very Large                        196
# Name: count, dtype: int64

# %%
df.drop(["DOF Gross Floor Area"],axis=1,inplace= True)

# %%
plt.boxplot(df["Year Built"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a3d1103ed0>,
#   <matplotlib.lines.Line2D at 0x2a3d1114ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a3d1115690>,
#   <matplotlib.lines.Line2D at 0x2a3d11161d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a3d1103350>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a3d1116d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a3d1115190>],
#  'means': []}

# %%
df["Year Built"].value_counts()
# Out:
# Year Built
# 1928    417
# 1927    412
# 1929    389
# 1930    369
# 1931    327
#        ...
# 1874      1
# 1867      1
# 1875      1
# 1860      1
# 2019      1
# Name: count, Length: 157, dtype: int64

# %%
bin_edges = [1500, 1800, 1850, 1900, 1950, 2000, 2050]  


bin_labels = ['Before 1800', '1800-1850', '1850-1900', '1900-1950', '1950-2000', 'After 2000']


df['Year Built Category'] = pd.cut(df['Year Built'], bins=bin_edges, labels=bin_labels, include_lowest=True)

# %%
df.drop(["Year Built"],axis=1,inplace= True)

# %%
df["Year Built Category"].value_counts()
# Out:
# Year Built Category
# 1900-1950      6179
# 1950-2000      4111
# After 2000     1145
# 1850-1900       294
# 1800-1850        15
# Before 1800       2
# Name: count, dtype: int64

# %%
df.drop(["Property GFA - Self-Reported (ft²)"],axis=1,inplace=True)

# %%
df_complete.replace(np.nan,0,inplace=True)

# %%
df.update(df_complete)

# %%
null_percentage=df.isnull().sum()/len(df) * 100 
null_percentage
# Out:
# Primary Property Type - Self Selected                       0.000000
# List of All Property Use Types at Property                  0.000000
# Largest Property Use Type                                   0.000000
# Largest Property Use Type - Gross Floor Area (ft²)          0.000000
# Metered Areas (Energy)                                      0.000000
# ENERGY STAR Score                                          17.912481
# Site EUI (kBtu/ft²)                                         0.000000
# Weather Normalized Site EUI (kBtu/ft²)                      0.000000
# Weather Normalized Site Electricity Intensity (kWh/ft²)     0.000000
# Weather Normalized Source EUI (kBtu/ft²)                    0.000000
# Natural Gas Use (kBtu)                                      0.000000
# Weather Normalized Site Natural Gas Use (therms)            0.000000
# Electricity Use - Grid Purchase (kBtu)                      0.000000
# Weather Normalized Site Electricity (kWh)                   0.000000
# Total GHG Emissions (Metric Tons CO2e)                      0.000000
# Direct GHG Emissions (Metric Tons CO2e)                     0.000000
# Indirect GHG Emissions (Metric Tons CO2e)                   0.000000
# Source EUI (kBtu/ft²)                                       0.000000
# Water Required?_Yes                                         0.000000
# Borough_encoded                                             0.000000
# DOF Gross Floor Area Category                               0.000000
# Year Built Category                                         0.000000
# dtype: float64

# %%
df_complete= df.select_dtypes(include=['float64', 'int64'])
df_complete=df_complete.drop(["ENERGY STAR Score"],axis=1)

# %%
df_complete.skew()   #almost all columns are highly skewed to the right
# Out:
# Site EUI (kBtu/ft²)                                         88.085861
# Weather Normalized Site EUI (kBtu/ft²)                      90.246739
# Weather Normalized Site Electricity Intensity (kWh/ft²)     42.465491
# Weather Normalized Source EUI (kBtu/ft²)                    84.279652
# Natural Gas Use (kBtu)                                     106.066803
# Weather Normalized Site Natural Gas Use (therms)           105.709124
# Electricity Use - Grid Purchase (kBtu)                      37.112254
# Weather Normalized Site Electricity (kWh)                   37.571319
# Total GHG Emissions (Metric Tons CO2e)                      94.453708
# Direct GHG Emissions (Metric Tons CO2e)                    106.066242
# Indirect GHG Emissions (Metric Tons CO2e)                   62.570631
# Source EUI (kBtu/ft²)                                       81.565151
# dtype: float64

# %%
sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
sns.barplot(x=df_complete.columns, y=df_complete.skew(), color='skyblue')
plt.title('Skewness of Numerical Columns')
plt.xlabel('Column')
plt.ylabel('Skewness')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df_complete[["Site EUI (kBtu/ft²)","Weather Normalized Site EUI (kBtu/ft²)","Weather Normalized Source EUI (kBtu/ft²)",
                         ]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a3d75bd610>,
#   <matplotlib.lines.Line2D at 0x2a3d8a85890>,
#   <matplotlib.lines.Line2D at 0x2a3d8a97850>,
#   <matplotlib.lines.Line2D at 0x2a3d8a9a9d0>,
#   <matplotlib.lines.Line2D at 0x2a3d8ab9650>,
#   <matplotlib.lines.Line2D at 0x2a3d8abba50>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a3d8a86710>,
#   <matplotlib.lines.Line2D at 0x2a3d8a6db10>,
#   <matplotlib.lines.Line2D at 0x2a3d8aa1510>,
#   <matplotlib.lines.Line2D at 0x2a3d8aa3c90>,
#   <matplotlib.lines.Line2D at 0x2a3d8ac2450>,
#   <matplotlib.lines.Line2D at 0x2a3d8ac8910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a3d8885e50>,
#   <matplotlib.lines.Line2D at 0x2a3d8a95990>,
#   <matplotlib.lines.Line2D at 0x2a3d8ab3290>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a3d8a6e950>,
#   <matplotlib.lines.Line2D at 0x2a3d8aa6150>,
#   <matplotlib.lines.Line2D at 0x2a3d8acacd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a3d8883750>,
#   <matplotlib.lines.Line2D at 0x2a3d8ab07d0>,
#   <matplotlib.lines.Line2D at 0x2a3d8ad1210>],
#  'means': []}

# %%
sns.boxplot(df_complete["Electricity Use - Grid Purchase (kBtu)"])
# Out:
# <Axes: >

# %%
# converting Electricity Use  to a categorical column based on area to low,medium,high and very high
bin_edges = [0, 15000, 1200000, 8000000, float('inf')]  


bin_labels = ['Low', 'Medium', 'High', 'Very High']


df['Electricity Use - Grid Purchase (kBtu)'] = pd.cut(df['Electricity Use - Grid Purchase (kBtu)'], bins=bin_edges, labels=bin_labels)
# Out:
#    Primary Property Type - Self Selected  \
# 0                                 Office
# 1  Hospital (General Medical & Surgical)
# 2  Hospital (General Medical & Surgical)
# 3  Hospital (General Medical & Surgical)
# 4  Hospital (General Medical & Surgical)
#
#   List of All Property Use Types at Property  \
# 0                                     Office
# 1      Hospital (General Medical & Surgical)
# 2      Hospital (General Medical & Surgical)
# 3      Hospital (General Medical & Surgical)
# 4      Hospital (General Medical & Surgical)
#
#                Largest Property Use Type  \
# 0                                 Office
# 1  Hospital (General Medical & Surgical)
# 2  Hospital (General Medical & Surgical)
# 3  Hospital (General Medical & Surgical)
# 4  Hospital (General Medical & Surgical)
#
#   Largest Property Use Type - Gross Floor Area (ft²) Metered Areas (Energy)  \
# 0                                             293447         Whole Building
# 1                                            3889181         Whole Building
# 2                                             231342         Whole Building
# 3                                            1305748         Whole Building
# 4                                             179694         Whole Building
#
#    ENERGY STAR Score  Site EUI (kBtu/ft²)  \
# 0                NaN                305.6
# 1               55.0                229.8
# 2                NaN                359.9
# 3                NaN                359.9
# 4                NaN                359.9
#
#    Weather Normalized Site EUI (kBtu/ft²)  \
# 0                                   303.1
# 1                                   228.8
# 2                                   359.9
# 3                                   359.9
# 4                                   359.9
#
#    Weather Normalized Site Electricity Intensity (kWh/ft²)  \
# 0                                               37.8
# 1                                               24.8
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Weather Normalized Source EUI (kBtu/ft²)  ...  \
# 0                                     614.2  ...
# 1                                     401.1  ...
# 2                                     414.2  ...
# 3                                     414.2  ...
# 4                                     414.2  ...
#
#    Electricity Use - Grid Purchase (kBtu)  \
# 0                               Very High
# 1                               Very High
# 2                               Very High
# 3                               Very High
# 4                               Very High
#
#    Weather Normalized Site Electricity (kWh)  \
# 0                                 11082770.5
# 1                                 96261312.1
# 2                                        0.0
# 3                                        0.0
# 4                                        0.0
#
#   Total GHG Emissions (Metric Tons CO2e)  \
# 0                                 6962.2
# 1                                55870.4
# 2                                    0.0
# 3                                    0.0
# 4                                    0.0
#
#    Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                      0.0
# 1                                  51016.4
# 2                                      0.0
# 3                                      0.0
# 4                                      0.0
#
#    Indirect GHG Emissions (Metric Tons CO2e)  Source EUI (kBtu/ft²)  \
# 0                                     6962.2                  619.4
# 1                                     4854.1                  404.3
# 2                                        0.0                  414.2
# 3                                        0.0                  414.2
# 4                                        0.0                  414.2
#
#    Water Required?_Yes  Borough_encoded DOF Gross Floor Area Category  \
# 0                    0                2                         Large
# 1                    0                2                    Very Large
# 2                    0                2                         Large
# 3                    0                2                         Large
# 4                    0                2                         Large
#
#    Year Built Category
# 0            1950-2000
# 1            1950-2000
# 2            1900-1950
# 3            1950-2000
# 4            1900-1950
#
# [5 rows x 22 columns]

# %%
df.drop(["Electricity Use - Grid Purchase (kBtu)"],axis=1,inplace=True)

# %%
df_complete= df.select_dtypes(include=['float64', 'int64'])
df_complete=df_complete.drop(["ENERGY STAR Score"],axis=1)

# %%
'Total GHG Emissions (Metric Tons CO2e)', 'Direct GHG Emissions (Metric Tons CO2e)','Indirect GHG Emissions (Metric Tons CO2e)',

# %%
plt.boxplot(df_complete[['Total GHG Emissions (Metric Tons CO2e)', 
                         'Direct GHG Emissions (Metric Tons CO2e)','Indirect GHG Emissions (Metric Tons CO2e)']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a3d113f290>,
#   <matplotlib.lines.Line2D at 0x2a3d932cc90>,
#   <matplotlib.lines.Line2D at 0x2a3d92f5490>,
#   <matplotlib.lines.Line2D at 0x2a3d92d89d0>,
#   <matplotlib.lines.Line2D at 0x2a3d93267d0>,
#   <matplotlib.lines.Line2D at 0x2a3d92eabd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a3d932dd90>,
#   <matplotlib.lines.Line2D at 0x2a3d93376d0>,
#   <matplotlib.lines.Line2D at 0x2a3d92da190>,
#   <matplotlib.lines.Line2D at 0x2a3d92b9ad0>,
#   <matplotlib.lines.Line2D at 0x2a3d92eaf50>,
#   <matplotlib.lines.Line2D at 0x2a3d92e1390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a3d947de50>,
#   <matplotlib.lines.Line2D at 0x2a3d92f5d90>,
#   <matplotlib.lines.Line2D at 0x2a3d93240d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a3d7588110>,
#   <matplotlib.lines.Line2D at 0x2a3d92aa8d0>,
#   <matplotlib.lines.Line2D at 0x2a3d92d5ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a3d927d190>,
#   <matplotlib.lines.Line2D at 0x2a3d9375d10>,
#   <matplotlib.lines.Line2D at 0x2a3d932c290>],
#  'means': []}

# %%
column_medians = df_complete.median()


df_complete = df_complete.apply(lambda x: x.mask(x > 800000, column_medians[x.name]))

# %%
plt.boxplot(df_complete[['Total GHG Emissions (Metric Tons CO2e)', 
                         'Direct GHG Emissions (Metric Tons CO2e)','Indirect GHG Emissions (Metric Tons CO2e)']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a3d92ade90>,
#   <matplotlib.lines.Line2D at 0x2a3d8c47290>,
#   <matplotlib.lines.Line2D at 0x2a3d8c57450>,
#   <matplotlib.lines.Line2D at 0x2a3d8c5ced0>,
#   <matplotlib.lines.Line2D at 0x2a3d8c6d390>,
#   <matplotlib.lines.Line2D at 0x2a3d8c6ee10>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a3d8c50d50>,
#   <matplotlib.lines.Line2D at 0x2a3d9375f50>,
#   <matplotlib.lines.Line2D at 0x2a3d8c5e410>,
#   <matplotlib.lines.Line2D at 0x2a3d8c5f990>,
#   <matplotlib.lines.Line2D at 0x2a3d8c740d0>,
#   <matplotlib.lines.Line2D at 0x2a3d8c75c50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a3d8c3ff10>,
#   <matplotlib.lines.Line2D at 0x2a3d8c560d0>,
#   <matplotlib.lines.Line2D at 0x2a3d8c67cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a3d8c531d0>,
#   <matplotlib.lines.Line2D at 0x2a3d8c64f90>,
#   <matplotlib.lines.Line2D at 0x2a3d8c771d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a3d92cf410>,
#   <matplotlib.lines.Line2D at 0x2a3d8c25ed0>,
#   <matplotlib.lines.Line2D at 0x2a3d8c5c7d0>],
#  'means': []}

# %%
plt.boxplot(df_complete[["Site EUI (kBtu/ft²)","Weather Normalized Site EUI (kBtu/ft²)","Weather Normalized Source EUI (kBtu/ft²)",
                         ]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a3d9777390>,
#   <matplotlib.lines.Line2D at 0x2a3d977d0d0>,
#   <matplotlib.lines.Line2D at 0x2a3d978d690>,
#   <matplotlib.lines.Line2D at 0x2a3d978e650>,
#   <matplotlib.lines.Line2D at 0x2a3d979eb50>,
#   <matplotlib.lines.Line2D at 0x2a3d97a81d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a3d977eb50>,
#   <matplotlib.lines.Line2D at 0x2a3d9765490>,
#   <matplotlib.lines.Line2D at 0x2a3d978fdd0>,
#   <matplotlib.lines.Line2D at 0x2a3d9799610>,
#   <matplotlib.lines.Line2D at 0x2a3d97a9790>,
#   <matplotlib.lines.Line2D at 0x2a3d97aac50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a3d9776090>,
#   <matplotlib.lines.Line2D at 0x2a3d9783f10>,
#   <matplotlib.lines.Line2D at 0x2a3d979d590>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a3d9781090>,
#   <matplotlib.lines.Line2D at 0x2a3d979ab90>,
#   <matplotlib.lines.Line2D at 0x2a3d97ac210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a3d977e4d0>,
#   <matplotlib.lines.Line2D at 0x2a3d94d6850>,
#   <matplotlib.lines.Line2D at 0x2a3d97ad510>],
#  'means': []}

# %%
df_complete=np.sqrt(df_complete)
# Out:
# C:\Users\91907\anaconda3.1\Lib\site-packages\pandas\core\internals\blocks.py:329: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)

# %%
df_complete.skew()
# Out:
# Site EUI (kBtu/ft²)                                        21.928239
# Weather Normalized Site EUI (kBtu/ft²)                     21.618166
# Weather Normalized Site Electricity Intensity (kWh/ft²)    21.621137
# Weather Normalized Source EUI (kBtu/ft²)                   20.170590
# Natural Gas Use (kBtu)                                     -0.911826
# Weather Normalized Site Natural Gas Use (therms)            0.954143
# Weather Normalized Site Electricity (kWh)                  -1.654355
# Total GHG Emissions (Metric Tons CO2e)                     12.791071
# Direct GHG Emissions (Metric Tons CO2e)                     5.679691
# Indirect GHG Emissions (Metric Tons CO2e)                  14.177337
# Source EUI (kBtu/ft²)                                      20.387374
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaled_df_complete=scaler.fit_transform(df_complete)

# %%
scaled_df_complete=pd.DataFrame(scaled_df_complete,columns=df_complete.columns)

# %%
# Out:
# Site EUI (kBtu/ft²)                                        53.241392
# Weather Normalized Site EUI (kBtu/ft²)                     52.677603
# Weather Normalized Site Electricity Intensity (kWh/ft²)     6.942221
# Weather Normalized Source EUI (kBtu/ft²)                   53.504522
# Natural Gas Use (kBtu)                                      1.416840
# Weather Normalized Site Natural Gas Use (therms)           -0.059619
# Weather Normalized Site Electricity (kWh)                   8.273225
# Total GHG Emissions (Metric Tons CO2e)                     15.539313
# Direct GHG Emissions (Metric Tons CO2e)                     4.370329
# Indirect GHG Emissions (Metric Tons CO2e)                   9.732382
# Source EUI (kBtu/ft²)                                      53.079960
# dtype: float64
